# %% [markdown]
# ## **Section 5: Streaming_data_storage: Kinesis(Amazon) Data Storage**

# %% [markdown]
# ## **1. Kinesis(Amazon) Data Firehouse, Data Buffer**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **2. Processing at Data Firehouse using Lambda**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **3. Iceberg Table Destination**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### summary
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **HandsON : 4. Send data from KDS to data Firehouse**

# %% [markdown]
# ## **HandsON : 5. Python SDK to write Records in Kinesis Data Firehouse**
