# %%
## boto3 documentation
## describe_stream
## get_records
## get_shard_iterator()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
