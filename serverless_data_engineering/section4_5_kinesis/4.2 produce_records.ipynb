# %%
#!pip3 install boto3 
# this doent work in UV

# %%
## Create a user 
## AWS CLI
## aws cli 
## provide access & secret key 
## ap-south-1
##

# %%
import boto3

# %%
### 
##  Activate ur virtial ENV 
# E:\repos>E:\repos\myenv\Scripts\activate.bat

# python -m ensurepip --upgrade
# python -m pip install --upgrade pip
# python -m pip install boto3


## now check in myenv/lib/site-packages/ <>library must be available

# %%
## Create Faker to generate data 
## user_data_1.csv
## user_data_2.csv
## user_data_3.csv 

## create Multi Threading to send the data to streams

# %% [markdown]
# ## Dataset
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Kinesis Prodicer
# ![image.png](attachment:image.png)
