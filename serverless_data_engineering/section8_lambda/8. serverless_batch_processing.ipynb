# %% [markdown]
# # **Servless Batch Processing : AWS Lambda**

# %% [markdown]
# ## **1. Intro to Servless Compute & AWS Lmabda use Cases**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Lambda functions & Its Component**

# %% [markdown]
# ## **2. HandsOn: Configure Lambda Functions & Its Components**
