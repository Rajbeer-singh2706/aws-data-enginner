# %%
# Section 4: Streaming Data Ingestion : AWS Kinesis Data Streams

# %%
# Introduction to Kinesis Data Streams(KDS)

# %%
# Kinesis Streams(KDS) -- Components & Capacity

# %%
# Hands ON : Create KDS
