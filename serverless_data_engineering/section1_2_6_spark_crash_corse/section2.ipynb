# %%
# Spark Crash course

# %% [markdown]
# ## **1. Distributed Compute & Storage , Big Data , Map Reduce**

# %%
# Big Data Ecosystem

# %%
2 + 5
# Out:
# 7

# %%
##

# %% [markdown]
# ## Spark Installation
