# %%
# Section 7 : Data Ingestion

# %%
# Ingestion 
# Veolcity 
# Volumne: 
# Variety 

### INgestion Type
 * Batch Ingestion 
 
#2. Streaming INgestion 
 * 

### Charaestrics 
* Throughput 
* Latency
* Replaybility
* Message delivery gura

### Change Data Capture(CDC)

# %%
# AWS DMS 
- MIgreation Task 
 * Include LOBs 
 * Target Table Prepartion
 * Miegration Type 
 * Table Mappings

# %%
# Schema COnversion Tool 
 -- Convert application code ,
 -- Sequence ,
 -- Users Defined Functions
 -- Schemas, 
 -- Tables 
 -- Views

# %%
# Apache Kafka
* Real time event processing 
* Log Aggregation 

# Kafka Producer 
# Kafka Consumer 
# Consumer Groups

# %%
# Amazon MSK (Managed Service for Apache Kafka)
- Provisioned 
- serverless

# Characteristics

# %%
# Amazon MSK Connect 
# Kafka Connect :

# %%
# Kinesis Data Streams 
 -- AWS SDK 
 00 Kinsis Producer Linrary(KPL)
 -- max single reford size 1MB
 --

# %%
# Kinesis data Streams Capacity
# Capacity MOdes 
 - On-Demand Capacity 
 - Provisioned Capacity 

* Provisioned THroughput Expection
- Enchanced Fan Out 
- Scalabityly 
  * scaliing up 
  * Scaling Down

# %%
# Kinesis Data Firehouse 
- AWS Lambda Integration (Can do some transformation)
- Dyanmic Partitioning 
    - Max THroughput:
    * Impoproived Performance
- Characteristice

# %%
# AWS Glue Schema Registry 
 - Schema and Registeries 
 - Compaitbilty Rules 
  * Diabled 
  * None 
  * Bckward
  * Forward
