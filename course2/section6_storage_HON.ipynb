# %%
# RDS 
# Create Parameter Group 
# Name: data-egineering-project-db-pg 
# MSQLCommunuty
# msql8.0
# Type: dbParameterGroup

# %%
# RDS 
# Free tier
# DbIdenigfier: data-egineering-project-db
# Credentials Slef Managed
# Additional Configuration: db_parameter_group: <data-egineering-project-db-pg >

# %%
## Connect RDS from Local Using 
## Before that change Securtiyr group of RDS
