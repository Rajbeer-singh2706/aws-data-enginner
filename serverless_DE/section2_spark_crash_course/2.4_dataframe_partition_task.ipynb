# %% [markdown]
# ## Tasks

# %%
# 1. Loading 1 Task 
# 2. saving (73 task )

## File Size : 9480169 KB
file_size = 9480169
file_size_mb = file_size / 1024
print(f"File size in MB: {file_size_mb} MB") #  9257.9775390625 MB

block_size = 128 
tasks = file_size_mb / block_size
print(f"Number of tasks: {tasks}")  # 73 tasks


## while writing it create 73 different files 
## 73 output partition created(73 different files )
# Out:
# File size in MB: 9257.9775390625 MB
# Number of tasks: 72.32794952392578

# %% [markdown]
# ![image.png](attachment:image.png)
