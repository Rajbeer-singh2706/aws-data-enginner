# %%
##### 1. 
# http://localhost:4040/jobs/

# %%
##
# Q) What is data block in AWS S3 ?
# Q) I have only 8 GB or ram in my system , but when i tried to load 10 GB file in pyspark dataframe 
# How its possible to load all the data in memory ?
