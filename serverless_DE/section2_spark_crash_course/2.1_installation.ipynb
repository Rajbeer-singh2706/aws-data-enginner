# %% [markdown]
# # Spark Crash course

# %% [markdown]
# ## **1. Distributed Compute & Storage , Big Data , Map Reduce**

# %%
#Q) AWS S3 Storage block size?

# %%
# Big Data Ecosystem

# %%
##

# %% [markdown]
# ## **2. File Format**

# %% [markdown]
# ## **3. Intro to spark,Batch & Stream Processing**

# %% [markdown]
# ## **4. Spark Installation**

# %%
## 1. Install JVM
## 2. nstall Scala
## 3. Install Spark

# %% [markdown]
# ## **5. Spark Standalone Cluster in Laptop**
