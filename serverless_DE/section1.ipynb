# %%
### Section 1:  Introdiction to serveless data processing on AWS

# %%
#1 . Data LIfecyls & Data Engineering

# %%
# AWS Servless offering for Data Enginneering

# %%
# Serverless Benefits
'''
* No need provision resources like servers
* Automatically scaled
* Automatic high-availability
* Auto Fault Tolerant
* Lesser cost for some workloads
* Which workloads ?
  * UNpredicatable and variable
  * Spiky workloads
'''
