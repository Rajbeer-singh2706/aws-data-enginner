# %%
# Section 8: Analytics # 5 HRS 
'''
* AWS GLUE 
* AWS GLue Studio
* AWS GLue Data Quality
* AWS Glue DataBrew
* AWS Lake Formation
* Amazon Athena
* Apache Spark
* Amazon EMR
* AMazpn Kinesis Data Streams 
* Amazon Data Firehouse
* Kinesis Data ANlautics / Amazon Managed Service for Apache Flink(MSAF)
* AMazn MSK
* Amazpn OPenSearch Service
* Amazon QUicksight
'''

# %%
# AWS GLUE 
# GLue, Hive and ETL 
'''
* DPU : Data processing units
* Enable Job Metrics , based on that we can select DPU
* DynamiCFrame
* Transformations
 -  resolveChoice
'''
# AWS GLue Jobs 
'''
 - Job Bookmarks
'''
# GLue Cost Model 
'''
'''
# AWS GLue Studio 
'''
'''
# AWS Glue Data Quality
'''
 DQDL 
'''
# AWS Glue DataBrew 
'''
'''

# NExt Glue Brew DEMo
