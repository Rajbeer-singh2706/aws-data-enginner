# %%
# Section 9: Application Integration
'''
 * Amazon SOS 
 * Amazon SNS 
 * AWS Step Functions
 * Amazon AppFlow
 * Amazon EventBRidge
 * Amazon Managed workflows for Apache Airflow (Amazon MWAA)
'''
