# %%
# Services:
# S3

# %%
# Setting up the Budget
# Bulling and Cost Manangemnt
# Budget and planning >> budget >> Monhtly cost budget >>> 20$
# email_recipient :

# %%
# Amazon S3 : 
'''
 Q) how it is programmed to find unique bucket name across the globe in s3 ?
 Q) Or when we create , where does it check , in database no ?
 * MaxObjectSize: 5TB
 *Metadata
 * Tags

'''
# Hands On:
'''
 Bucket : 
 BucketType: General Purpose (select) / DirectoryBucket
 BucketName: 
 OBjectOwernship
 Blocing public : block 
 Bucket Versioning
 Tags
 Enruption: Server Side 
 BucketKey : enable
'''
# Upload the jpg file (coffee.jpg)
# Now see the Object Properties 
# Click on Open --> u can open ( its presigned URL) --> can open it 
# Cant access public URL ( access Denined)

## Create a Imges folder 
## Upload beach.jpg file 

## Delete
# permanently Delete

# %% [markdown]
# ### Amazon S3 Security : Bucket policy
