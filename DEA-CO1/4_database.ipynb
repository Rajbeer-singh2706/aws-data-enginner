# %%
# Section 4: Database
'''
 1. DynamoDB
 2. RDS
 3. Amazon Aurora
 4. DocumentDB
 5. MemoryDB for redis
 6. Amazon KeySpaces(for apache cassandra)
 7. Amazon Neptune
 8. Amazon timestream
 9. Amazon redshift ***
'''
